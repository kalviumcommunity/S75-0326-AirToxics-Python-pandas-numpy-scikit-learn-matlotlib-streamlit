# %% [markdown]
# # Jupyter Kernel Management: Run, Restart, Interrupt

# %% [markdown]
# ## Purpose
# This notebook demonstrates how to run cells, restart the kernel, and interrupt execution in Jupyter Notebook.

# %%
x = 10
print("Value of x:", x)
# Out:
# Value of x: 10

# %%
print("x + 5 =", x + 5)
# Out:
# x + 5 = 15

# %%
print(x)
# Out:
# 10

# %% [markdown]
# ### Kernel Restart
# Restarting the kernel clears all variables and memory.
# This ensures a clean and reproducible notebook state.

# %%
print(x)
# Out:
# 10
