# %% [markdown]
# # Markdown Practice in Jupyter Notebook

# %% [markdown]
# ## Introduction
# This notebook demonstrates how to use Markdown for documentation.

# %% [markdown]
# ## Steps Involved
#
# ### Step 1: Load Data
# ### Step 2: Process Data
# ### Step 3: Display Results

# %% [markdown]
# ## Tools Used
# - Python
# - Jupyter Notebook
# - Markdown

# %% [markdown]
# ## Workflow
# 1. Import libraries
# 2. Load dataset
# 3. Clean data
# 4. Analyze results

# %% [markdown]
# Use the `print()` function to display output.

# %% [markdown]
# ```python
# x = 10
# print(x)
# ```

# %%
x = 10
y = 20
print(x + y)
# Out:
# 30

# %% [markdown]
# ### Explanation
# The above code adds two numbers and prints the result.

# %% [markdown]
# ### Output Interpretation
# The result shows the sum of x and y, which is 30.
