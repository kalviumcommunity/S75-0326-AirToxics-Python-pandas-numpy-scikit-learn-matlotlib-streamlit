# %% [markdown]
# # Code vs Markdown in Jupyter Notebook

# %% [markdown]
# ## Purpose
# This notebook demonstrates the difference between Code cells and Markdown cells, and how to use them properly.

# %%
a = 5
b = 10
print("Sum:", a + b)

# %% [markdown]
# ### Explanation
# This code adds two numbers (5 and 10) and prints the result.

# %%
name = "Dhanya"
print("Hello", name)
# Out:
# Hello Dhanya

# %% [markdown]
# ### Explanation
# This code prints a greeting message using a variable.

# %% [markdown]
# This is a test

# %% [markdown]
# ## Markdown Features
#
# - Bullet points
# - **Bold text**
# - *Italic text*
#
# ### Subheading Example
# Markdown helps explain code clearly.
